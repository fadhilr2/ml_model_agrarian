# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error

# %%
df = pd.read_csv("../model_ready_data.csv")
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

# %%
ct = ColumnTransformer(transformers=[("encoder", OneHotEncoder(), [0])], remainder="passthrough")
X = np.array(ct.fit_transform(X))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# %%
# FOR DEGREE TESTING
# BEWARE 

# for i in range(1, 11):
#   regressor = LinearRegression()
#   poly = PolynomialFeatures(degree=i)
#   X_poly_features = poly.fit_transform(X)
#   regressor.fit(X_poly_features, y)

#   print(i)
#   test_input = np.array(ct.transform([[
#   "Carrots and turnips", 25.83762295, 18.24245902, 22.04004098, 7.595163934, 2139.885, 3.097377049, 0.747459016, 8.437459016]]))
#   print(regressor.predict(poly.transform(test_input)))
#   print(y[0])

# %%
regressor = LinearRegression()
poly = PolynomialFeatures(degree=3)
X_poly_features = poly.fit_transform(X_train)
regressor.fit(X_poly_features, y_train)
# Out:
# LinearRegression()

# %%
test_input = np.array(ct.transform([[
  "Carrots and turnips", 25.83762295, 18.24245902, 22.04004098, 7.595163934, 2139.885, 3.097377049, 0.747459016, 8.437459016]]))
print(regressor.predict(poly.transform(test_input)))
# Out:
# [0.93459065]

# %%
y_pred = regressor.predict(poly.transform(X_test))

np.concatenate([y_pred.reshape(-1, 1), y_test.reshape(-1, 1)], 1)
# Out:
# array([[ 1.10078068e+00,  1.36646000e+00],
#        [ 6.73904727e-01,  1.18439000e+00],
#        [ 2.49137731e-01,  5.83390000e-01],
#        [ 6.87282522e-01,  6.20020000e-01],
#        [-3.44121073e-02,  2.02300000e-02],
#        [ 1.07730135e+00,  1.12487000e+00],
#        [ 9.64145388e-01,  1.15963000e+00],
#        [ 1.49646861e-01,  8.37200000e-02],
#        [ 6.50454442e-01,  5.03280000e-01],
#        [ 1.12177642e+00,  1.66494000e+00],
#        [ 1.83786381e-02,  2.33800000e-02],
#        [ 8.79321481e-02,  1.14920000e-01],
#        [ 5.65548477e-01,  9.02800000e-01],
#        [ 1.51207688e+00,  1.94064000e+00],
#        [-2.06638718e-02,  9.73500000e-02],
#        [ 1.34495612e-01,  1.18300000e-01],
#        [ 1.32035213e+00,  1.31355000e+00],
#        [ 8.17229218e-01,  5.98720000e-01],
#        [-9.43668524e-02,  1.55800000e-02],
#        [ 4.73969235e-01,  9.39100000e-02],
#        [ 1.00935364e+00,  1.09243000e+00],
#        [ 1.53838840e+00,  1.73104000e+00],
# ...

# %%
print("r2 " + str(r2_score(y_test, y_pred)))
print("mse " + str(mean_squared_error(y_test, y_pred)))
# Out:
# r2 0.46236835902005813
# mse 0.1766539604930424
